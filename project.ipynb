# %%
#Load the dataset

import numpy as np
import pandas as pd
path = "/Users/nikita_agarwal/Desktop/ML/project/bmw.csv"
Dataset = pd.read_csv(path)

# %%
Dataset.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
Dataset.head(5)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
Dataset.shape
# Out:
# (10781, 9)

# %%
Dataset.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
# All avilable BMW model in the market
Dataset.model.unique()
# Out:
# array([' 5 Series', ' 6 Series', ' 1 Series', ' 7 Series', ' 2 Series',
#        ' 4 Series', ' X3', ' 3 Series', ' X5', ' X4', ' i3', ' X1', ' M4',
#        ' X2', ' X6', ' 8 Series', ' Z4', ' X7', ' M5', ' i8', ' M2',
#        ' M3', ' M6', ' Z3'], dtype=object)

# %%
#bar plot for avilable BMW model in the market
Dataset['model'].value_counts(sort=False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
# All avilable BMW trasmission in the market
Dataset.transmission.unique()
# Out:
# array(['Automatic', 'Manual', 'Semi-Auto'], dtype=object)

# %%
#bar plot for avilable BMW transmission in the market
Dataset['transmission'].value_counts(sort=False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
# All avilable BMW fueltype in the market
Dataset.fuelType.unique()
# Out:
# array(['Diesel', 'Petrol', 'Other', 'Hybrid', 'Electric'], dtype=object)

# %%
#bar plot for avilable BMW fueltype in the market
Dataset['fuelType'].value_counts(sort=False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
Dataset.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
# COLLECTING ALL THE DATA TOGETHER HAVING DATATYPE AS OBJECT
obj_df = Dataset.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#        model transmission fuelType
# 0   5 Series    Automatic   Diesel
# 1   6 Series    Automatic   Petrol
# 2   5 Series    Automatic   Diesel
# 3   1 Series    Automatic   Diesel
# 4   7 Series    Automatic   Diesel

# %%
# OrdinalEncoder TO COVERT Model INTO NUMERICAL VALUES

from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["model"] = ord_enc.fit_transform(Dataset[["model"]])

# %%
# OrdinalEncoder TO COVERT transmission INTO NUMERICAL VALUES

from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["transmission"] = ord_enc.fit_transform(Dataset[["transmission"]])

# %%
# OrdinalEncoder TO COVERT fueltype INTO NUMERICAL VALUES

from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
Dataset["fuelType"] = ord_enc.fit_transform(Dataset[["fuelType"]])

# %%
Dataset.head(20)
# Out:
#     model  year  price  transmission  mileage  fuelType  tax    mpg  \
# 0     4.0  2014  11200           0.0    67068       0.0  125   57.6
# 1     5.0  2018  27000           0.0    14827       4.0  145   42.8
# 2     4.0  2016  16000           0.0    62794       0.0  160   51.4
# 3     0.0  2017  12750           0.0    26676       0.0  145   72.4
# 4     6.0  2014  14500           0.0    39554       0.0  160   50.4
# 5     4.0  2016  14900           0.0    35309       0.0  125   60.1
# 6     4.0  2017  16000           0.0    38538       0.0  125   60.1
# 7     1.0  2018  16250           1.0    10401       4.0  145   52.3
# 8     3.0  2017  14250           1.0    42668       0.0   30   62.8
# 9     4.0  2016  14250           0.0    36099       0.0   20   68.9
# 10   15.0  2017  15500           1.0    74907       0.0  145   52.3
# 11    0.0  2017  11800           1.0    29840       0.0   20   68.9
# 12   15.0  2016  15500           0.0    77823       0.0  125   54.3
# ...

# %%
Dataset.describe()
# Out:
#               model          year          price  transmission        mileage  \
# count  10781.000000  10781.000000   10781.000000  10781.000000   10781.000000
# mean       5.297839   2017.078935   22733.408867      1.099991   25496.986550
# std        6.054688      2.349038   11415.528189      0.869297   25143.192559
# min        0.000000   1996.000000    1200.000000      0.000000       1.000000
# 25%        1.000000   2016.000000   14950.000000      0.000000    5529.000000
# 50%        2.000000   2017.000000   20462.000000      1.000000   18347.000000
# 75%       10.000000   2019.000000   27940.000000      2.000000   38206.000000
# max       23.000000   2020.000000  123456.000000      2.000000  214000.000000
#
#            fuelType           tax           mpg    engineSize
# count  10781.000000  10781.000000  10781.000000  10781.000000
# mean       1.333364    131.702068     56.399035      2.167767
# std        1.853240     61.510755     31.336958      0.552054
# ...

# %%
# Count number of duplicated rows
len(Dataset[Dataset.duplicated(keep= False)])
# Out:
# 179

# %%
# Show entire rows
Dataset[Dataset.duplicated(keep= False)]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 173          X4  2019  33998    Semi-Auto     7272   Diesel  150  42.8
# 174          X4  2019  33998    Semi-Auto     7272   Diesel  150  42.8
# 379          X1  2018  16995    Semi-Auto    17276   Petrol  150  46.3
# 393          X1  2018  16995    Semi-Auto    17276   Petrol  150  46.3
# 643    1 Series  2019  21898       Manual     4100   Petrol  150  41.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 9797   4 Series  2019  25449    Automatic     6890   Diesel  145  65.7
# 9939         M3  2009  16950       Manual    65000   Petrol  580  21.9
# 9940         M3  2009  16950       Manual    65000   Petrol  580  21.9
# 9942   3 Series  2013  10985    Automatic    70000   Diesel  165  50.4
# 9943   3 Series  2013  10985    Automatic    70000   Diesel  165  50.4
#
#       engineSize
# 173          2.0
# 174          2.0
# 379          1.5
# 393          1.5
# 643          1.5
# ...

# %%
# Drop the repeated rows
df=Dataset.drop_duplicates()

# %%
#check for any null values in dataset
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.describe()
# Out:
#               model          year          price  transmission        mileage  \
# count  10664.000000  10664.000000   10664.000000  10664.000000   10664.000000
# mean       5.285634   2017.062828   22692.888691      1.102682   25710.978995
# std        6.050988      2.350668   11434.921030      0.869770   25146.634940
# min        0.000000   1996.000000    1200.000000      0.000000       1.000000
# 25%        1.000000   2016.000000   14897.000000      0.000000    5665.750000
# 50%        2.000000   2017.000000   20261.500000      1.000000   18783.000000
# 75%       10.000000   2019.000000   27890.000000      2.000000   38436.500000
# max       23.000000   2020.000000  123456.000000      2.000000  214000.000000
#
#            fuelType           tax           mpg    engineSize
# count  10664.000000  10664.000000  10664.000000  10664.000000
# mean       1.318923    131.597431     56.483121      2.170161
# std        1.847723     61.611394     31.465604      0.552556
# ...

# %%
# code to plot histogram and box plot
import matplotlib.pyplot as plt
def plots(df,col):
    fig, ax = plt.subplots(1, 2, figsize=(10,4))
    ax[0].hist(df[col])
    ax[0].set_title(col + ' hist')
    ax[1].boxplot(df[col])
    ax[1].set_title(col + ' boxplot')
    plt.show()

# %%
plots(df,'mileage')

# %%
plots(df,'year')

# %%
plots(df,'model')

# %%
plots(df,'price')

# %%
plots(df,'transmission')

# %%
plots(df,'fuelType')

# %%
plots(df,'tax')

# %%
plots(df,'mpg')

# %%
plots(df,'engineSize')

# %%
# outlier removal
#  removing outlier in year
df = df[df['year'] > 2000]

# %%
#  removing outlier in price
df = df[df['price'] < 99950]

# %%
#  removing outlier in mileage
df = df[df['mileage'] < 178987]

# %%
#  removing outlier in tax
df = df[df['tax'] >20]

# %%
#  removing outlier in mpg
df = df[df['mpg'] > 8 ]

# %%
df = df[df['mpg'] < 470.8 ]

# %%
# 6) removing outlier in engineSize
df = df[df['engineSize'] > 1 ]

# %%
df = df[df['engineSize'] < 5 ]

# %%
df.shape
# Out:
# (9799, 9)

# %%
# box plot after removol of outlier
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,figsize=(20,20))
plt.show()

# %%
# histogram with cleaned dataset
import matplotlib.pyplot as plt
df.hist(figsize=(10,10))
plt.show()

# %%
# density plot with cleaned dataset
df.plot(kind='density', subplots=True, layout=(3,3), figsize=[15,15], sharex=False)
plt.show()

# %%
#scatter matrix plot with cleaned dataset
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=[15,15])
plt.show()

# %%
#correlation matrix

import seaborn as sns
sns.heatmap(df.corr(), cmap='Blues', annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# split  the dataset
X = df.drop('price',axis=1)
y = df['price']

# %%
X.head(5)
# Out:
#    model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 0    4.0  2014           0.0    67068       0.0  125  57.6         2.0
# 1    5.0  2018           0.0    14827       4.0  145  42.8         2.0
# 2    4.0  2016           0.0    62794       0.0  160  51.4         3.0
# 3    0.0  2017           0.0    26676       0.0  145  72.4         1.5
# 4    6.0  2014           0.0    39554       0.0  160  50.4         3.0

# %%
#standardise dataset-X
array=X.values
for i in range(len(X.columns)):
    mean_val = array[:,i].mean()
    std_val = array[:,i].std()
    array[:,i]= ((array[:,i] - mean_val)/std_val)

# %%
print(array)
# Out:
# [[-0.24294051 -1.36773426 -1.28328797 ... -0.31212905  0.32801357
#   -0.39786222]
#  [-0.07659476  0.34871027 -1.28328797 ...  0.06866684 -0.67206072
#   -0.39786222]
#  [-0.24294051 -0.50951199 -1.28328797 ...  0.35426376 -0.09093647
#    1.47973933]
#  ...
#  [-0.57563201 -0.08040086 -0.1486729  ...  1.11585554 -0.67206072
#   -0.39786222]
#  [-0.90832351 -1.36773426 -1.28328797 ... -2.12090954  0.77399265
#   -0.39786222]
#  [ 1.25417125 -0.08040086 -1.28328797 ... -0.31212905  0.32801357
#   -0.39786222]]

# %%
X_scaled = array

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, 
                                    test_size = 0.20,random_state =42)
                                               
models = []

models.append(('LR', LinearRegression()))
models.append(('R', Ridge()))
models.append(('L', Lasso()))
models.append(('BR', BayesianRidge(n_iter=1000)))
models.append(('KNR', KNeighborsRegressor()))
models.append(('DTR', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
models.append(('ABR', AdaBoostRegressor(n_estimators=300)))
models.append(('BR', BaggingRegressor(n_estimators=300)))
models.append(('ETR', ExtraTreesRegressor(n_estimators=300)))
models.append(('GBR', GradientBoostingRegressor(n_estimators=300)))
models.append(('RFR', RandomForestRegressor(n_estimators=300)))


for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    m_score = r2_score(y_test, m_predict)
    print("%s: r2_score = %.3f" % (name, m_score))
# Out:
# LR: r2_score = 0.761
# R: r2_score = 0.761
# L: r2_score = 0.761
# BR: r2_score = 0.761
# KNR: r2_score = 0.933
# DTR: r2_score = 0.903
# SVR: r2_score = 0.008
# ABR: r2_score = 0.689
# BR: r2_score = 0.953
# ETR: r2_score = 0.953
# GBR: r2_score = 0.955
# RFR: r2_score = 0.953

# %%
# Root mean square error on standardise dataset
from sklearn.metrics import mean_squared_error
from math import sqrt
for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    rmse = sqrt(mean_squared_error(y_test, m_predict))
    
    print("%s: Root Mean Squared Error = %.3f" % (name, rmse))
# Out:
# LR: Root Mean Squared Error = 5566.262
# R: Root Mean Squared Error = 5566.288
# L: Root Mean Squared Error = 5566.216
# BR: Root Mean Squared Error = 5566.365
# KNR: Root Mean Squared Error = 2946.857
# DTR: Root Mean Squared Error = 3541.547
# SVR: Root Mean Squared Error = 11348.393
# ABR: Root Mean Squared Error = 7456.760
# BR: Root Mean Squared Error = 2464.032
# ETR: Root Mean Squared Error = 2472.653
# GBR: Root Mean Squared Error = 2408.301
# RFR: Root Mean Squared Error = 2474.418

# %%
model_name = ['LR','R','L','BAR','KNR','DTR','SVR','ABR','BR','ETR','GBR','RFR']
score = [0.761,0.761,0.761,0.761,0.933,0.903,0.008,0.742,0.952,0.953,0.955,0.953]

# %%
# Plotting a Bar Graph to compare the R2_score from different models
plt.figure(figsize=(7,7))
plt.bar(model_name, score)
plt.xlabel('Regression_model')
plt.ylabel('R2_Score')
#plt.title('Comparison of different Feature Importances')
plt.show()

# %%
# Principal component analysis
from numpy import array
from sklearn.decomposition import PCA
# create the PCA instance
pca = PCA(3)
# fit on data
pca.fit(X_scaled)
# access values and vectors
print("pca_components\n")
print(pca.components_)
print("pca_explained_variance\n")
print(pca.explained_variance_ratio_)
# transform data
B = pca.transform(X_scaled)
print(B)
# Out:
# pca_components
#
# [[-0.20420068 -0.43986813 -0.28833212  0.4989552  -0.32968904 -0.3196728
#    0.41710962 -0.21877021]
#  [ 0.29242717 -0.43917929 -0.21042697  0.38528652  0.00589261  0.41948676
#   -0.34747058  0.48181222]
#  [-0.54850183 -0.22665351 -0.06251661  0.13446028  0.6908727   0.13953776
#   -0.2110305  -0.29064805]]
# pca_explained_variance
#
# [0.27478519 0.23340058 0.15266574]
# [[ 2.46106219  1.03273956  0.25169681]
#  [-0.62632209  0.02805757  1.21369101]
#  [ 1.1982221   1.91857022 -0.33053554]
#  ...
#  [-0.78147221  0.43797805  1.71809823]
#  [ 2.91301678 -0.42162152  0.14938121]
#  [ 1.43402206  0.78542105 -0.90303972]]

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

X_train, X_test, y_train, y_test = train_test_split(B, y, test_size = 0.20,
                                                    random_state =42)
models = []

models.append(('LR', LinearRegression()))
models.append(('R', Ridge()))
models.append(('L', Lasso()))
models.append(('BR', BayesianRidge(n_iter=1000)))
models.append(('KNR', KNeighborsRegressor()))
models.append(('DTR', DecisionTreeRegressor()))
models.append(('SVR', SVR()))
models.append(('ABR', AdaBoostRegressor(n_estimators=300)))
models.append(('BR', BaggingRegressor(n_estimators=300)))
models.append(('ETR', ExtraTreesRegressor(n_estimators=300)))
models.append(('GBR', GradientBoostingRegressor(n_estimators=300)))
models.append(('RFR', RandomForestRegressor(n_estimators=300)))



for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    m_score = r2_score(y_test, m_predict)
    print("%s: r2_score = %.3f" % (name, m_score))
# Out:
# LR: r2_score = 0.684
# R: r2_score = 0.684
# L: r2_score = 0.684
# BR: r2_score = 0.684
# KNR: r2_score = 0.918
# DTR: r2_score = 0.847
# SVR: r2_score = 0.031
# ABR: r2_score = 0.676
# BR: r2_score = 0.920
# ETR: r2_score = 0.924
# GBR: r2_score = 0.867
# RFR: r2_score = 0.921

# %%
model_name = ['LR','R','L','BAR','KNR','DTR','SVR','ABR','BR','ETR','GBR','RFR']
score = [0.684,0.684,0.684,0.684,0.918,0.47,0.031,0.676,0.920,0.924,0.867,0.921]

# %%
#Plotting a Bar Graph to compare the models
plt.figure(figsize=(7,7))
plt.bar(model_name, score)
plt.xlabel('Regression_model')
plt.ylabel('R2_Score')
#plt.title('Comparison of different Feature Importances')
plt.show()

# %%
# Root mean square error after applying pca on standardise dataset
from sklearn.metrics import mean_squared_error
from math import sqrt
for name, model in models:
    model.fit(X_train, y_train)
    m_predict = model.predict(X_test)
    rmse = sqrt(mean_squared_error(y_test, m_predict))
    
    print("%s: Root Mean Squared Error = %.3f" % (name, rmse))
# Out:
# LR: Root Mean Squared Error = 5566.262
# R: Root Mean Squared Error = 5566.288
# L: Root Mean Squared Error = 5566.216
# BR: Root Mean Squared Error = 5566.365
# KNR: Root Mean Squared Error = 2946.857
# DTR: Root Mean Squared Error = 3453.756
# SVR: Root Mean Squared Error = 11348.393
# ABR: Root Mean Squared Error = 5971.693
# BR: Root Mean Squared Error = 2476.385
# ETR: Root Mean Squared Error = 2451.979
# GBR: Root Mean Squared Error = 2411.199
# RFR: Root Mean Squared Error = 2468.806

# %%
#predication model on extra tree regressor
ETR = ExtraTreesRegressor()
ETR.fit(X_train, y_train)

y_pred = ETR.predict(X_test) #predicts the price using Extra Tree Regressor using linear features.

# %%
y_test = y_test.reset_index(drop=True)
y_pred_df = pd.DataFrame({'Price_prediction': y_pred.flatten()})

# %%
print(y_test)
# Out:
# 0       13998
# 1       33998
# 2       13480
# 3       25490
# 4       26995
#         ...
# 1955    15699
# 1956    23976
# 1957    24990
# 1958    26450
# 1959    34994
# Name: price, Length: 1960, dtype: int64

# %%
print(y_pred_df)
# Out:
#       Price_prediction
# 0            14109.220
# 1            35051.320
# 2            14237.900
# 3            29520.600
# 4            28970.950
# ...                ...
# 1955         14978.650
# 1956         23030.830
# 1957         28991.065
# 1958         20113.070
# 1959         36069.360
#
# [1960 rows x 1 columns]

# %%
#Comparing the predicted price vs original price by joining them

Comparison= pd.merge(y_test, y_pred_df, left_index=True, right_index=True)
Comparison.head(10)
# Out:
#       price  Price_prediction
# 586   13998          14852.48
# 955   33998          20522.49
# 1253  13480          20433.05
# 1917  17980          20760.76
# 291   21498          25770.75
# 572   14995          55227.10
# 1795  12290          17212.05
# 120   19000          24049.50
# 638   22998          23162.16
# 1047  10298          18189.03

# %%
print(Comparison)
# Out:
#       price  Price_prediction
# 586   13998          14852.48
# 955   33998          20522.49
# 1253  13480          20433.05
# 1917  17980          20760.76
# 291   21498          25770.75
# ...     ...               ...
# 1628  23920          33907.21
# 1860  22480          19947.42
# 1303  34370          23092.00
# 40    15800          19313.19
# 1518  23976          20320.11
#
# [374 rows x 2 columns]

# %%
x = 50
comparison = Comparison.head(x)
comparison.plot(kind = 'bar', figsize = (20,15))
bmw_pred = plt.grid(linestyle = '-', linewidth = '0.6', color = 'green', which = 'both')
plt.show()

# %%
plt.savefig('bmw_prediction_vs_price.png')

# %%
#extra tree classifier for feature selection

import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

# Building the model
extra_tree_forest = ExtraTreesClassifier(n_estimators = 5,
                                criterion ='entropy', max_features = 2)
  
# Training the model
extra_tree_forest.fit(X, y)
  
# Computing the importance of each feature
feature_importance = extra_tree_forest.feature_importances_
  
# Normalizing the individual importances
feature_importance_normalized = np.std([tree.feature_importances_ for 
                                        tree in 
                                        extra_tree_forest.estimators_],
                                        axis = 0)

# %%
# Plotting a Bar Graph to compare the different features
plt.figure(figsize=(15,15))
plt.bar(X.columns, feature_importance_normalized)
plt.xlabel('Feature Labels')
plt.ylabel('Feature Importances')
plt.title('Comparison of different Feature Importances')
plt.show()
